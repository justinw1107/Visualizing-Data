# %%
# install.packages("corrplot")
# install.packages("GGally")
# install.packages("ggExtra")

library(tidyverse)
library(corrplot)
library(GGally)
library(ggExtra)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0     ✔ purrr   1.0.1
# ✔ tibble  3.1.8     ✔ dplyr   1.1.0
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.3     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# corrplot 0.92 loaded
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
mydata = file.path("C:","Users","thehd","OneDrive","College","YEAR_4","Visualizing_Data","Labwork","VisDataLab7")
datapath = file.path(mydata, "data.csv")

CD <- read.csv(datapath)

# %%
options(repr.plot.width=19, repr.plot.height=19)
plot(CD)
# Out:
# plot without title

# %%
summary(CD)
# Out:
#    private               apps           accept          enroll
#  Length:777         Min.   :   81   Min.   :   72   Min.   :  35
#  Class :character   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242
#  Mode  :character   Median : 1558   Median : 1110   Median : 434
#                     Mean   : 3002   Mean   : 2019   Mean   : 780
#                     3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902
#                     Max.   :48094   Max.   :26330   Max.   :6392
#    top10perc       top25perc      f_undergrad     p_undergrad
#  Min.   : 1.00   Min.   :  9.0   Min.   :  139   Min.   :    1.0
#  1st Qu.:15.00   1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0
#  Median :23.00   Median : 54.0   Median : 1707   Median :  353.0
#  Mean   :27.56   Mean   : 55.8   Mean   : 3700   Mean   :  855.3
#  3rd Qu.:35.00   3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0
#  Max.   :96.00   Max.   :100.0   Max.   :31643   Max.   :21836.0
#     outstate       room_board       books           personal
# ...

# %%
colnames(CD)
# Out:
#  [1] "private"     "apps"        "accept"      "enroll"      "top10perc"
#  [6] "top25perc"   "f_undergrad" "p_undergrad" "outstate"    "room_board"
# [11] "books"       "personal"    "phd"         "terminal"    "s_f_ratio"
# [16] "perc_alumni" "expend"      "grad_rate"

# %%
CD1 <- subset(CD, select=c(personal, expend, grad_rate))

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(CD1)
# Out:
# plot without title

# %%
ggpairs(CD)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# ...

# %%
CD1corr = cor(CD1)
corrplot(CD1corr)
# Out:
# Plot with title ""

# %%
corrplot(CD1corr, method = 'number')
# Out:
# Plot with title ""

# %%
corrplot(CD1corr, method = 'color', order = 'alphabet')
# Out:
# Plot with title ""

# %%
corrplot.mixed(CD1corr, lower = 'shade', upper = 'pie', order = 'hclust')
# Out:
# Plot with title ""

# %%
# install.packages('ggpubr')
library(ggpubr)

# %%
ggscatter(CD, x = "accept", y = "s_f_ratio",
         add = "reg.line", conf.int = TRUE,
         cor.coef = TRUE, cor.method = "pearson",
         xlab = "Accepted Applications", ylab = "Student to Faculty ratio")
# Out:
# plot without title

# %%
ggqqplot(CD$books, ylab = "Books")
ggqqplot(CD$perc_alumni, ylab = "Percentage of Alumni that donate")
# Out:
# plot without title
# plot without title

# %%
str(CD)
# Out:
# 'data.frame':	777 obs. of  18 variables:
#  $ private    : chr  "Yes" "Yes" "Yes" "Yes" ...
#  $ apps       : int  1660 2186 1428 417 193 587 353 1899 1038 582 ...
#  $ accept     : int  1232 1924 1097 349 146 479 340 1720 839 498 ...
#  $ enroll     : int  721 512 336 137 55 158 103 489 227 172 ...
#  $ top10perc  : int  23 16 22 60 16 38 17 37 30 21 ...
#  $ top25perc  : int  52 29 50 89 44 62 45 68 63 44 ...
#  $ f_undergrad: int  2885 2683 1036 510 249 678 416 1594 973 799 ...
#  $ p_undergrad: int  537 1227 99 63 869 41 230 32 306 78 ...
#  $ outstate   : int  7440 12280 11250 12960 7560 13500 13290 13868 15595 10468 ...
#  $ room_board : int  3300 6450 3750 5450 4120 3335 5720 4826 4400 3380 ...
#  $ books      : int  450 750 400 450 800 500 500 450 300 660 ...
#  $ personal   : int  2200 1500 1165 875 1500 675 1500 850 500 1800 ...
#  $ phd        : int  70 29 53 92 76 67 90 89 79 40 ...
#  $ terminal   : int  78 30 66 97 72 73 93 100 84 41 ...
# ...

# %%
CD %>% summarise_all(list(~n_distinct(.)))
# Out:
#   private apps accept enroll top10perc top25perc f_undergrad p_undergrad
# 1 2       711  693    581    82        89        714         566
#   outstate room_board books personal phd terminal s_f_ratio perc_alumni expend
# 1 640      553        122   294      78  65       173       61          744
#   grad_rate
# 1 81

# %%
unique(CD$private)
unique(CD$perc_alumni)
# Out:
# [1] "Yes" "No"
#  [1] 12 16 30 37  2 11 26 23 15 31 41 21 32 19 63 14 18  5 35 25 24 40 33 20 38
# [26] 10 17 29 13  9 34 53  3 52 39 49 36  8 27 60 22  4  0  6 45  7 28 55 43 51
# [51] 42 46 44 47 54 58 48 57 50  1 64

# %%
CD$private[CD$private == 'Yes'] <- 1
CD$private[CD$private == 'No'] <- 0

# %%
CD$private <- as.factor(CD$private)
CD$grad_rate <- as.factor(CD$grad_rate)
CD$perc_alumni <- as.factor(CD$perc_alumni)

# %%
str(CD)
# Out:
# 'data.frame':	777 obs. of  18 variables:
#  $ private    : Factor w/ 2 levels "0","1": 2 2 2 2 2 2 2 2 2 2 ...
#  $ apps       : int  1660 2186 1428 417 193 587 353 1899 1038 582 ...
#  $ accept     : int  1232 1924 1097 349 146 479 340 1720 839 498 ...
#  $ enroll     : int  721 512 336 137 55 158 103 489 227 172 ...
#  $ top10perc  : int  23 16 22 60 16 38 17 37 30 21 ...
#  $ top25perc  : int  52 29 50 89 44 62 45 68 63 44 ...
#  $ f_undergrad: int  2885 2683 1036 510 249 678 416 1594 973 799 ...
#  $ p_undergrad: int  537 1227 99 63 869 41 230 32 306 78 ...
#  $ outstate   : int  7440 12280 11250 12960 7560 13500 13290 13868 15595 10468 ...
#  $ room_board : int  3300 6450 3750 5450 4120 3335 5720 4826 4400 3380 ...
#  $ books      : int  450 750 400 450 800 500 500 450 300 660 ...
#  $ personal   : int  2200 1500 1165 875 1500 675 1500 850 500 1800 ...
#  $ phd        : int  70 29 53 92 76 67 90 89 79 40 ...
#  $ terminal   : int  78 30 66 97 72 73 93 100 84 41 ...
# ...

# %%
p <- ggplot(CD, aes(x=accept, y=s_f_ratio, shape = private, color = grad_rate, size = perc_alumni)) +  # shape = color
  geom_point()+ theme_bw()+
theme(legend.position="bottom") 
p
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title
